# %% [markdown]
# 🧠 Нейролингвистическое программирование (НЛП)
# — метод в психологии для изменения поведения и мышления с помощью языка.
# 🟡 Применяется в коучинге, переговорах, личностном росте.
# 🔴 Научно не подтверждён, считается псевдонаукой.
#
# 🤖 Natural Language Processing (NLP)
# — область искусственного интеллекта, изучающая, как компьютеры понимают и обрабатывают человеческий язык.
# 🟢 Используется в чат-ботах, переводчиках, голосовых помощниках.
# 🔵 Основан на математике, лингвистике и машинном обучении.

# %% [markdown]
# Natural Language Understanding (NLU) - анализ естественных языков (понимание текста)
# Синтаксический анализ - анализ структуры языков (например сказуемое и подлежащее)
# Семантический анализ - анализ значения, смысла
# Natural Language Generation (NLG) - генерация естественных языков (генерация текстов)

# %% [markdown]
# Машинное обучение — это раздел искусственного интеллекта, где компьютер учится находить закономерности в данных и делать предсказания без явного программирования правил.
#
#
#
# Глубинное обучение — это подраздел машинного обучения, где используются нейронные сети с несколькими слоями (отсюда слово "глубинное").
#
# Каждый слой обучается извлекать всё более сложные признаки из данных (например, сначала контуры на фото, потом формы, потом объекты).
#
# Зачем оно:
# Распознавание образов (фото, речь)
#
# Обработка текста (NLP)
#
# Генерация изображений, перевод, ChatGPT и др.
#
# 📌 Главное отличие от обычного ML:
#
# Не требует ручной работы по созданию признаков (feature engineering)
#
# Требует много данных и мощных видеокарт (GPU)
#
# 🗣 А как тут связан NLP (Natural Language Processing)?
# NLP — это область, где ИИ работает с человеческим языком:
#
# Классификация текста
#
# Перевод
#
# Чат-боты
#
# Поиск по смыслу
#
# Генерация текста
#
# 📌 Раньше NLP строилось на классических ML алгоритмах, но теперь почти всё:
#
# 🔥 делается с помощью Deep Learning — трансформеров (BERT, GPT и др.)
