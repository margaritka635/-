# %%
import pandas as pd

# %%
data = pd.read_csv("data_sem1.csv", delimiter=";")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund; Mr. Owen Harris    male  22.0      1
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen; Miss. Laina  female  26.0      0
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen; Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Sex'].isnull().sum()
# Out:
# 0

# %%
data["Sex"].value_counts()
# Out:
# Sex
# male       574
# female     312
# unknown      5
# Name: count, dtype: int64

# %%
def ini_sex(name):
    if "Mr." in name:
        return "male"
    elif "Mrs." in name or "Miss." in name: 
        return "female"
    else:
        return "male"
    return "unknown"

# %%
data.loc[data["Sex"] == "unknown", "Sex"] = data["Name"].apply(ini_sex)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund; Mr. Owen Harris    male  22.0      1
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen; Miss. Laina  female  26.0      0
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen; Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
if data["Sex"] == "unknown":
    print(data["PassengerId"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zh/j8rqhvlx2yd78_s9795t28zr0000gn/T/ipykernel_46148/346313399.py in ?()
# ----> 1 if data["Sex"] == "unknown":
#       2     print(data["PassengerId"])
#       3
#
# ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
